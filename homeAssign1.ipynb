# %%
# !pip install nltk scikit-learn
# Out:
# Requirement already satisfied: nltk in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.9.4)
# Requirement already satisfied: scikit-learn in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.8.0)
# Requirement already satisfied: click in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (2026.3.32)
# Requirement already satisfied: tqdm in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in C:\Users\kartik ware\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
import re

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import nltk
#       2 import re
#       4 from nltk.tokenize import word_tokenize, sent_tokenize
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\__init__.py:147
#     141 from nltk.jsontags import *
#     143 ###########################################################
#     144 # PACKAGES
#     145 ###########################################################
# --> 147 from nltk.chunk import *
#     148 from nltk.classify import *
#     149 from nltk.inference import *
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\chunk\__init__.py:155
#       1 # Natural Language Toolkit: Chunkers
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      7 # For license information, see LICENSE.TXT
#       8 #
#      10 """
#      11 Classes and interfaces for identifying non-overlapping linguistic
#      12 groups (such as base noun phrases) in unrestricted text.  This task is
#    (...)    152      pattern is valid.
#     153 """
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.named_entity import Maxent_NE_Chunker
#     157 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\chunk\api.py:15
#      13 from nltk.chunk.util import ChunkScore
#      14 from nltk.internals import deprecated
# ---> 15 from nltk.parse import ParserI
#      18 class ChunkParserI(ParserI):
#      19     """
#      20     A processing interface for identifying non-overlapping groups in
#      21     unrestricted text.  Typically, chunk parsers are used to find base
#    (...)     24     will always generate a parse.
#      25     """
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\parse\__init__.py:78
#      71 from nltk.parse.evaluate import DependencyEvaluator
#      72 from nltk.parse.featurechart import (
#      73     FeatureBottomUpChartParser,
#      74     FeatureBottomUpLeftCornerChartParser,
#      75     FeatureChartParser,
#      76     FeatureTopDownChartParser,
#      77 )
# ---> 78 from nltk.parse.malt import MaltParser
#      79 from nltk.parse.nonprojectivedependencyparser import (
#      80     NaiveBayesDependencyScorer,
#      81     NonprojectiveDependencyParser,
#      82     ProbabilisticNonprojectiveParser,
#      83 )
#      84 from nltk.parse.pchart import (
#      85     BottomUpProbabilisticChartParser,
#      86     InsideChartParser,
#    (...)     89     UnsortedChartParser,
#      90 )
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369     module = sys.modules.get(name, _NEEDS_LOADING)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#    1377 _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:1342, in _find_and_load_unlocked(name, import_)
#    1340     parent_spec._uninitialized_submodules.append(child)
#    1341 try:
# -> 1342     module = _load_unlocked(spec)
#    1343 finally:
#    1344     if parent_spec:
#
# File <frozen importlib._bootstrap>:938, in _load_unlocked(spec)
#     935             raise ImportError('missing loader', name=spec.name)
#     936         # A namespace package so do nothing.
#     937     else:
# --> 938         spec.loader.exec_module(module)
#     939 except:
#     940     try:
#
# File <frozen importlib._bootstrap_external>:758, in _LoaderBasics.exec_module(self, module)
#     756 def exec_module(self, module):
#     757     """Execute the module."""
# --> 758     code = self.get_code(module.__name__)
#     759     if code is None:
#     760         raise ImportError(f'cannot load module {module.__name__!r} when '
#     761                           'get_code() returns None')
#
# File <frozen importlib._bootstrap_external>:854, in SourceLoader.get_code(self, fullname)
#     852 source_mtime = int(st['mtime'])
#     853 try:
# --> 854     data = self.get_data(bytecode_path)
#     855 except OSError:
#     856     pass
#
# File <frozen importlib._bootstrap_external>:954, in FileLoader.get_data(self, path)
#     952 if isinstance(self, (SourceLoader, ExtensionFileLoader)):
#     953     with _io.open_code(str(path)) as file:
# --> 954         return file.read()
#     955 else:
#     956     with _io.FileIO(path, 'r') as file:
#
# KeyboardInterrupt:

# %%
text = """Natural Language Processing (NLP) is a field of Artificial Intelligence. 
It helps computers understand human language. 
Text preprocessing is an important step in NLP."""

# %%
#Lowercase Conversion
text_lower = text.lower()
print("Lowercase:\n", text_lower)

# %%
#Remove Punctuation
text_clean = re.sub(r'[^a-zA-Z ]', '', text_lower)
print("\nCleaned Text:\n", text_clean)

# %%
#Sentence Tokenization
sentences = sent_tokenize(text)
print("\nSentences:\n", sentences)

# %%
#Word Tokenization
words = word_tokenize(text_clean)
print("\nWords:\n", words)

# %%
#Remove Stopwords
stop_words = set(stopwords.words('english'))

filtered_words = [word for word in words if word not in stop_words]

print("\nAfter Stopword Removal:\n", filtered_words)

# %%
#Stemming
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]

print("\nStemmed Words:\n", stemmed_words)

# %%
#Lemmatization
lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

print("\nLemmatized Words:\n", lemmatized_words)

# %%
#Bag of Words (BoW)
corpus = [text_clean]

cv = CountVectorizer()
bow = cv.fit_transform(corpus)

print("\nBag of Words:\n", bow.toarray())
print("Feature Names:\n", cv.get_feature_names_out())

# %%
#TF-IDF Representation
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(corpus)

print("\nTF-IDF:\n", tfidf_matrix.toarray())
print("Feature Names:\n", tfidf.get_feature_names_out())
